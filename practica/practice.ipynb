# %%
import numpy as np
import cv2


# Load an color image in grayscale
img = cv2.imread('pics/messi.jpg',1)
print(img)
# Out:
# [[[236 148   0]
#   [236 148   0]
#   [236 148   0]
#   ...
#   [240 156   4]
#   [240 156   4]
#   [240 156   4]]
#
#  [[236 148   0]
#   [236 148   0]
#   [236 148   0]
#   ...
#   [240 156   4]
#   [240 156   4]
#   [240 156   4]]
#
#  [[236 148   0]
#   [236 148   0]
#   [236 148   0]
#   ...
#   [239 155   3]
#   [239 155   3]
#   [239 155   3]]
#
#  ...
#
#  [[ 83 105   3]
#   [ 83 105   3]
#   [ 83 105   3]
#   ...
#   [124 137 129]
#   [125 138 130]
#   [125 138 130]]
#
#  [[ 82 105   1]
#   [ 82 105   1]
#   [ 82 105   1]
#   ...
#   [114 131 127]
#   [115 132 128]
#   [116 133 129]]
#
#  [[ 82 105   1]
#   [ 82 105   1]
#   [ 82 105   1]
#   ...
#   [110 131 129]
#   [111 132 130]
#   [112 133 131]]]

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('pics/messi.jpg',0)
cv2.imshow('image',img)
k = cv2.waitKey(0) & 0xFF
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('pics/messigray.png',img)
    cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt
img = cv2.imread('pics/messi.jpg',0)
plt.imshow(img,cmap='gray', interpolation = 'nearest')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
